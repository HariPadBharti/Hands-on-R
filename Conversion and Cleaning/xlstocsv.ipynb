# %%
import pandas as pd

# %%
xl = pd.ExcelFile("hd.xls")

# %%
xl.sheet_names
# Out:
# ['Visual_Analytics_Data', 'Questions']

# %%
df1 = xl.parse("Visual_Analytics_Data")
df1
# Out:
#                                                 Qname        Q1  \
# 0   What is your first name?Entering your name mea...  Your age
# 1                                                 NaN       NaN
# 2                                                Alex        29
# 3                                                Ayat        33
# 4                                               Bobby        28
# 5                                               Chris        43
# 6                                               Elias        29
# 7                                              Harold        58
# 8                                             Jessica        26
# 9                                              Lauren        25
# 10                                               Luke        23
# 11                                            Manjula        34
# 12                                           Manpreet        23
# 13                                              David        26
# ...

# %%
df.to_csv('out.csv')

# %%
import csv
df=pd.DataFrame()
df=pd.read_csv('hd.csv', skiprows=0)

# %%
df
# Out:
#                                                 Qname        Q1  \
# 0   What is your first name?Entering your name mea...  Your age
# 1                                                Alex        29
# 2                                                Ayat        33
# 3                                               Bobby        28
# 4                                               Chris        43
# 5                                               Elias        29
# 6                                              Harold        58
# 7                                             Jessica        26
# 8                                              Lauren        25
# 9                                                Luke        23
# 10                                            Manjula        34
# 11                                           Manpreet        23
# 12                                              David        26
# 13                                            Michael        22
# ...
